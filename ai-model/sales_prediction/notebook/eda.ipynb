# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../data/raw_sales.csv")

# Preview
print(df.head())
print("\nColumns:", df.columns)
print("\nShape:", df.shape)
print("\nMissing values:\n", df.isnull().sum())
# Out:
#          date               item_name   category  quantity_sold  price  \
# 0  2025-03-17        Margherita Pizza  Fast Food             32   12.5
# 1  2025-03-17  Grilled Chicken Burger  Fast Food             18   10.0
# 2  2025-03-17            Caesar Salad        Veg             15    8.5
# 3  2025-03-17                    Cola   Beverage             25    3.0
# 4  2025-03-18     Spaghetti Bolognese      Pasta             18   14.0
#
#   day_of_week  holiday weather
# 0      Monday        0   Sunny
# 1      Monday        0   Sunny
# 2      Monday        0   Sunny
# 3      Monday        0   Sunny
# 4     Tuesday        0  Cloudy
#
# Columns: Index(['date', 'item_name', 'category', 'quantity_sold', 'price',
#        'day_of_week', 'holiday', 'weather'],
#       dtype='object')
#
# Shape: (553, 8)
#
# Missing values:
#  date             0
# item_name        0
# category         0
# quantity_sold    0
# price            0
# day_of_week      0
# holiday          0
# weather          0
# ...
